# %% [markdown]
# <a href="https://colab.research.google.com/github/saimayasmeen4/AEFPNC/blob/main/AEFPNC_master_saima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
path, dirs, files = next(os.walk('/content/drive/MyDrive/ADNet/gray/data/rain'))
file_count = len(files)
print(file_count)
# Out:
# 2608

# %%
# import os
# input_dir='/content/drive/MyDrive/ADNet/gray/data/rain'
# img_names = os.listdir(input_dir)
# img_names.sort()
# print(img_names)
# len(img_names)

# %%
cd /content/drive/MyDrive/AEFPNC-master/
# Out:
# /content/drive/MyDrive/AEFPNC-master

# %%
# !python train.py
# Out:
# Loading Data
# Starting training
# epoch [1/250], loss:3908.1870
# Time elapsed: 3771.6028
# Saving model: ./Checkpoints/AEFPNC_Gray_1.pth
# epoch [2/250], loss:2321.7720
# Time elapsed: 530.6070
# epoch [3/250], loss:2911.9177
# Time elapsed: 530.3909
# epoch [4/250], loss:2680.3289
# Time elapsed: 530.5945
# epoch [5/250], loss:2052.3032
# Time elapsed: 530.6174
# epoch [6/250], loss:3398.3828
# Time elapsed: 529.9718
# Saving model: ./Checkpoints/AEFPNC_Gray_6.pth
# epoch [7/250], loss:2033.1570
# Time elapsed: 530.0474
# epoch [8/250], loss:1987.7053
# Time elapsed: 530.3553
# epoch [9/250], loss:2758.4534
# Time elapsed: 530.7009
# epoch [10/250], loss:1876.4297
# Time elapsed: 530.4337
# epoch [11/250], loss:2944.9917
# Time elapsed: 530.1326
# Saving model: ./Checkpoints/AEFPNC_Gray_11.pth
# epoch [12/250], loss:2098.8701
# Time elapsed: 529.6783
# epoch [13/250], loss:1354.2295
# Time elapsed: 529.4627
# epoch [14/250], loss:2719.0254
# Time elapsed: 529.5124
# ...

# %%
# !python evaluate.py
# Out:
# Saved Image 1
# Saved Image 2
# Saved Image 3
# Saved Image 4
# Saved Image 5
# Saved Image 6
# Saved Image 7
# Saved Image 8
# Saved Image 9
# Saved Image 10
# Saved Image 11
# Saved Image 12
# Saved Image 13
# Saved Image 14
# Saved Image 15
# Saved Image 16
# Saved Image 17
# Saved Image 18
# Saved Image 19
# Saved Image 20
# Saved Image 21
# Saved Image 22
# Saved Image 23
# Saved Image 24
# Saved Image 25
# Saved Image 26
# Saved Image 27
# Saved Image 28
# Saved Image 29
# Saved Image 30
# Saved Image 31
# Saved Image 32
# Saved Image 33
# Saved Image 34
# Saved Image 35
# Saved Image 36
# Saved Image 37
# Saved Image 38
# Saved Image 39
# Saved Image 40
# Saved Image 41
# Saved Image 42
# Saved Image 43
# Saved Image 44
# Saved Image 45
# Saved Image 46
# Saved Image 47
# Saved Image 48
# Saved Image 49
# Saved Image 50
# Saved Image 51
# Saved Image 52
# Saved Image 53
# Saved Image 54
# Saved Image 55
# Saved Image 56
# Saved Image 57
# Saved Image 58
# Saved Image 59
# ...
